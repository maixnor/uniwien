# %% [markdown]
# # Aufgabenblatt 4

# %% [markdown]
# ## Eindimensionale Analysis – Grenzwerte

# %%
from sympy import *
x = symbols("x", real = true)

# %% [markdown]
# ### Aufgabe 1
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 4} \frac{x-4}{x^2-x-12}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$\lim_{x\rightarrow4} \frac{x-4}{(x-4)(x+3)}$$
# $$\lim_{x\rightarrow4} \frac{1}{x+3} = \frac{1}{7}$$

# %%
y = (x - 4) / (x**2 - x - 12)
plot(y, xlim = (-12, 8), ylim = (-5,5))

# %% [markdown]
# ### Aufgabe 2
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow -1} \frac{x^2+3x+2}{x^4+4x+3}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# wenn fuer $x$ wir einsetzten $-1$ bekommen wir $0/0$. Demnach koennen wir diese Nullstelle herausheben.
#
# $$\lim_{x\rightarrow-1} \frac{(x+1)(x+2)}{(x+1)(x^3 - x^2 + x + 3)}$$
# $$\lim_{x\rightarrow-1} \frac{x+2}{x^3 - x^2 + x + 3}$$
# $$\lim_{x\rightarrow-1} \frac{x+2}{x^3 - x^2 + x + 3} = \frac{1}{0} = \infty$$

# %%
y = (x**2 + 3*x + 2)/(x**4+4*x+3)

plot(y, xlim=(-8, 6), ylim=(-4, 4))

# %%
y.limit(x, -1)
# Out:
# oo

# %% [markdown]
# ### Aufgabe 3
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 1} \frac{x^4+2x^2-3}{x^2-3x+2}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# ### Aufgabe 4
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0}x^2\log{x}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$\lim_{x\rightarrow 0} x^2 \log{x}$$
# $$\lim_{x\rightarrow 0} \frac{\log{x}}{\frac{1}{x^2}}$$
# Le' Hospital (Lopittal)
# $$\lim_{x\rightarrow 0} \frac{\log{x}}{\frac{1}{x^2}} = \lim_{x\rightarrow 0} \frac{\frac{1}{x}}{\frac{-2}{x^3}} = \lim_{x\rightarrow 0} -\frac{x^3}{2x}$$
# $$\lim_{x\rightarrow 0} -\frac{x^3}{2x} = \lim_{x\rightarrow 0} -\frac{x^2}{2} = \frac{0}{2} = 0$$

# %%
y = x**2 * log(x)

plot(y, xlim=(-2,10), ylim=(-2,10))

# %%
y.limit(x, 0)
# Out:
# 0

# %% [markdown]
# ### Aufgabe 5
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0} \frac{\sin{x}}{x}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$\lim_{x\rightarrow 0} \frac{\sin{x}}{x} = \frac{0}{0}$$
# Le' Hospital
# $$\lim_{x\rightarrow 0} \frac{\sin{x}}{x} = \lim_{x\rightarrow 0} \frac{\cos(x)}{1} = \frac{1}{1} = 1$$

# %%
y = sin(x) / x

plot(y, xlim=(-10,10), ylim=(-1,1))

# %%
y.limit(x, 0)
# Out:
# 1

# %% [markdown]
# ### Aufgabe 6
#
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0} x^{(x^2)}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$\lim_{x \rightarrow 0} = x^{(x^2)} = \lim_{x \rightarrow 0} e^{\ln(x) * x^2}$$
# Bereits oben geloest bei Aufgabe 4
# $$e^0 = 1$$

# %%
y = x ** (x ** 2)

plot(y, xlim=(-2,10), ylim=(-2,10))
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
y.limit(x,0)
# Out:
# 1

# %% [markdown]
# ### Aufgabe 7
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow \infty} (\log{(x+1)}-\log{x})
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$\lim_{x \rightarrow \infty} (\log{x+1} - \log{x}) = \lim_{x \rightarrow \infty} \log{\frac{x+1}{x}} = \lim_{x \rightarrow \infty} \log{\frac{1+\frac{1}{x}}{1}} = \log{1} = 0$$

# %%
y = log(x+1) - log(x)

plot(y, xlim=(-10,10), ylim=(-10,10))

# %%
y.limit(x, oo)
# Out:
# 0

# %% [markdown]
# ### Aufgabe 8
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0} (\sin{x})^x
# $$
#
# Plotten Sie die Funktion.
